# %% [markdown]
# # Day 8
#
# # Numpy

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#numpy was made in 2005 by merging numeric and Numarray by Travis Oliphant.
# numpy is written in C which are compiled and super fast.
#This is the main reason numPy is up to 50PX faster than python list.

# %%
# Numpy Arrays
# - [1,2,3,4] - array and list but what diff.

# list - datatype - mixed , performance - slower, Memory Efficiency - Low, Vector operations - Manual loops.

# Numpy array - datatype - Same datatype only, performance - Faster(c-level), Memory Efficiency - High, vector operations - Easy Fast.

import numpy as np

# Basic Array creation
arr = np.array([1,2,3,4])
print(arr)

a = [1,2,3,4,5,'hello']

print(np.array(a))
# Out:
# [1 2 3 4]
# ['1' '2' '3' '4' '5' 'hello']
