# %% [markdown]
# # Day 5
#
# # Function

# %%
# A function is a reusable block of code that performs a specific task.
# Define with `def`, optionally take parameters, and optionally return a value.

def greet(name):
    """Return a greeting for name."""
    return f"Hello, {name}!"

print(greet("Alice"))        # Hello, Alice!
print(greet.__doc__)         # show the docstring

def add(a, b=0):
    """Add two numbers, b defaults to 0."""
    return a + b

print(add(3, 4), add(5))     # 7 5

def summarize(*args, **kwargs):
    """Demonstrate positional (*args) and keyword (**kwargs) arguments."""
    return f"args={args}, kwargs={kwargs}"

print(summarize(1, 2, x=10)) # args=(1, 2), kwargs={'x': 10}

# Anonymous (lambda) functions and passing functions around
square = lambda x: x * x
def apply(func, value):
    return func(value)

print(square(5), apply(square, 7))  # 25 49

# %%
# Parameters vs Arguments
# - Parameter: a variable name in a function definition (a placeholder).
# - Argument: the actual value passed to the function when it is called.

def greet(name, punctuation='!'):  # name and punctuation are parameters
    return f"Hello, {name}{punctuation}"

# "Alice" and "?" are arguments passed into the parameters 'name' and 'punctuation'
print(greet("Alice"))        # Hello, Alice!
print(greet("Bob", "?"))     # Hello, Bob?

# positional vs keyword arguments
def add(a, b=0):  # a and b are parameters
    return a + b

print(add(3, 4))         # positional arguments: 3 and 4
print(add(a=5, b=2))     # keyword arguments
print(add(5))            # single argument; b uses its default value (0)
# Out:
# Hello, Alice!
# Hello, Bob?
# 7
# 7
# 5

# %%
import asyncio

# Callback: pass a function to be called inside another function
def apply_and_show(func, value):
    """func is a callback here."""
    print("calling callback...")
    result = func(value)
    print("result:", result)
    return result

def square(x):
    return x * x

apply_and_show(square, 5)            # callback as named function
apply_and_show(lambda x: x + 1, 10)  # callback as lambda

# Closure: nested function capturing outer variable
def make_multiplier(n):
    def multiply(x):
        return x * n
    return multiply

double = make_multiplier(2)
print(double(7))  # 14

# Generator function
def count_to(n):
    for i in range(1, n + 1):
        yield i

print(list(count_to(4)))  # [1, 2, 3, 4]

# Recursive function
def factorial(n):
    return 1 if n <= 1 else n * factorial(n - 1)

print(factorial(5))  # 120

# Coroutine (async) function

async def greet_async(name):
    await asyncio.sleep(0)
    return f"Hello, {name} (async)"

# print(asyncio.run(greet_async("Alice")))

# Method types: instance, static, and class
class C:
    def instance_method(self):
        return "instance"

    @staticmethod
    def static_method():
        return "static"

    @classmethod
    def class_method(cls):
        return f"class {cls.__name__}"

c = C()
print(C.instance_method(), C.static_method(), C.class_method())
# Out:
# calling callback...
# result: 25
# calling callback...
# result: 11
# 14
# [1, 2, 3, 4]
# 120
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 45
#      42     await asyncio.sleep(0)
#      43     return f"Hello, {name} (async)"
# ---> 45 print(asyncio.run(greet_async("Alice")))
#      47 # Method types: instance, static, and class
#      48 class C:
#
# File c:\Python313\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
