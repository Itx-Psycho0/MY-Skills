# %% [markdown]
# # Day 5
#
# # Searching and Sorting

# %% [markdown]
# # Soritng Algo
#
# - In computer science, a sorting algorithm is an algorithm that puts elements if a list into an order. the most frequently used orders are numerical order and lexicogrsphical order, and either ascending or descending.
